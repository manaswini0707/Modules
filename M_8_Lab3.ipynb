# %% [markdown]
# <a href="https://colab.research.google.com/github/manaswini0707/Modules/blob/main/M_8_Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-16 06:44:49--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   166MB/s    in 0.4s
#
# 2022-06-16 06:44:51 (166 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 2935 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 15  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22194  1507.04436v1  We consider factoring low-rank tensors in the ...  stat
# 27182  1702.06722v1  Object reconstruction is one of the main probl...    cs
# 6844   1706.07101v1  We explore the energy landscape of a simple ne...  stat
# 22178  1506.07959v1  Factorial hidden Markov models (FHMMs) are pow...  stat
# 6011   1605.09196v3  We propose a novel methodology, forest floor, ...  stat
# ...             ...                                                ...   ...
# 14576  cs/0305041v2  Factorization of statistical language models i...    cs
# 10370   1301.5288v3  Reconstruction of a function from noisy data i...  stat
# 22418  1606.05201v2  Decoding, ie prediction from brain images or s...  stat
# 7609   1802.04868v1  The aim of knowledge graphs is to gather knowl...  stat
# 14116  1711.05993v1  We apply the approach of evolutionary programm...    cs
#
#                                                    title  year  \
# 22194  Joint Tensor Factorization and Outlying Slab S...  2015
# 27182  3D Reconstruction of Temples in the Special Re...  2017
# 6844     The energy landscape of a simple neural network  2017
# 22178  Factorized Asymptotic Bayesian Inference for F...  2015
# 6011       Forest Floor Visualizations of Random Forests  2016
# ...                                                  ...   ...
# 14576  Factorization of Language Models through Backi...  2003
# 10370  The connection between Bayesian estimation of ...  2013
# 22418  Assessing and tuning brain decoders: cross-val...  2016
# 7609   SimplE Embedding for Link Prediction in Knowle...  2018
# 14116  On evolutionary selection of blackjack strategies  2017
#
#                                                 keywords
# 22194  [factoring, important, collected, applications...
# 27182  [reconstruction, preservation, documentation, ...
# 6844   [landscape, particular, demonstrating, empiric...
# 22178  [factorial, sequential, challenging, simultane...
# 6011   [methodology, visualize, interpret, classifica...
# ...                                                  ...
# 14576  [factorization, statistical, discriminative, d...
# 10370  [reconstruction, formulated, regularized, opti...
# 22418  [prediction, empirical, evaluation, predictive...
# 7609   [knowledge, knowledge, structured, representat...
# 14116  [evolutionary, programming, optimization, blac...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22194    [factoring, important, collected, applications...
# 27182    [reconstruction, preservation, documentation, ...
# 6844     [landscape, particular, demonstrating, empiric...
# 22178    [factorial, sequential, challenging, simultane...
# 6011     [methodology, visualize, interpret, classifica...
#                                ...
# 7639     [dissimilar, investigate, orthogonality, promo...
# 36801    [interaction, categories, interaction, coordin...
# 20981    [modalities, empirical, successes, understand,...
# 8858     [companies, providing, controlled, recognize, ...
# 11417    [incremental, semiparametric, particular, appr...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8879 words.
# Out of those 4610 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c6ccbd0a-df4f-4f01-a029-ed6e6dea7de1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c6ccbd0a-df4f-4f01-a029-ed6e6dea7de1")) {                    Plotly.newPlot(                        "c6ccbd0a-df4f-4f01-a029-ed6e6dea7de1",                        [{"x":["alternating","factoring","selecting","optimization","suppression","effectiveness","algorithm","important","formulate","promoting","minimization","fluorescence","iteration","simulations","regularization","procedure","factorization","separation","convergence","incorporated","applications","trilinear","constraints","experiments","iteratively","information","complexity","collected","framework","corresponding","reconstruction","keypoints","utilizing","performing","descriptor","photogrammetry","documentation","reconstructed","presented","comparing","preservation","commercial","texturing","parameter","beneficial","generalization","empirical","landscape","demonstrating","particular","outperforms","integrate","dimensionality","nonparametric","asymptotic","experimental","transition","factorial","contribution","probabilities","eliminate","redundant","selection","perplexity","extending","approximation","significantly","factorized","inference","challenging","variational","sequential","simultaneous","parsimonious","likelihood","competitive","visualizations","prediction","introduce","dimensional","visualize","nonetheless","visualization","difficult","subsequently","dependence","consequence","gradients","decompose","averaging","traditional","reduction","methodology","classification","structure","contributions","interpretation","visualized","advantages","projection","interpret","projections","furthermore","validated","splitting","robustness","interactions","regression","geometrical","qualities","specialized","classifiers","generative","distorted","arbitrary","attention","observations","simultaneously","symmetries","attributes","theoretical","improvement","organically","demonstrate","statistics","situation","baselines","different","recognized","refinement","qualitative","designing","quantitative","substantial","segmentation","guidelines","represented","autonomous","convolutional","evaluations","assessing","addressing","incomplete","correctly","simulated","correspond","adversarial","supervised","discriminator","efficient","generating","classifier","belonging","pertaining","discrepancy","distributions","conditions","connections","reproducing","projected","associated","divergences","incorporates","hypothesis","bhattacharyya","application","divergence","populations","neuroimaging","intermediate","characterize","differences","discriminate","approaches","investigated","systematic","simulation","additionally","providing","processes","algorithmic","considerations","computation","frequency","thresholded","tractable","decomposed","performance","graphical","otherwise","partition","connected","concentration","estimated","infeasible","components","thresholding","algorithms","covariance","denoising"],"y":[24,1,38,323,5,216,786,348,48,4,54,2,28,50,90,119,47,29,124,17,436,0,158,619,31,703,229,67,516,129,116,9,36,85,40,3,5,26,169,80,8,22,2,135,23,109,156,10,38,271,254,43,67,18,18,361,20,2,70,54,8,14,160,9,31,110,287,8,224,250,46,70,31,3,53,108,7,226,345,171,17,4,34,154,26,25,21,37,20,19,185,104,57,505,336,63,46,3,72,43,24,22,170,30,11,97,74,105,9,5,26,110,125,10,77,186,70,117,8,60,168,139,1,551,66,37,64,711,23,24,66,49,82,54,186,12,80,55,374,50,20,21,38,35,55,34,126,193,16,401,112,165,10,6,20,123,133,43,8,19,109,7,31,47,0,266,22,18,6,25,41,51,8,428,51,33,79,70,83,108,47,7,132,50,2,21,8,902,52,22,19,75,7,66,16,113,12,565,16,51],"type":"bar"},{"x":["alternating","factoring","selecting","optimization","suppression","effe ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4610,), (4610, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8225

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Multiarmed</span> <span style=''>Bandit</span> <span style=''>Problems</span> <span style=''>with</span> <span style=''>Delayed</span> <span style=''>Feedback</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>initiate</span> <span style=''>the</span> <span style=''>study</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>of</span> <span style=''>bandit</span> <span style=''>type</span> <span style=''>problems</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>scenarios</span> <span style=''>where</span> <span style=''>the</span> <span style=''>feedback</span> <span style=''>of</span> <span style=''>a</span> <span style=''>play</span> <span style=''>is</span> <span style=''>not</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>immediately</span> <span style=''>known</span> <span style=''>This</span> <span style=''>arises</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>naturally</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>allocation</span> <span style=''>problems</span> <span style=''>which</span> <span style=''>have</span> <span style=''>been</span> <span style=''>studied</span> <span style='background-color:rgba(0, 255, 0, 0.320754716981132);'>extensively</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>literature</span> <span style=''>albeit</span> <span style=''>in</span> <span style=''>the</span> <span style=''>absence</span> <span style=''>of</span> <span style=''>delays</span> <span style=''>in</span> <span style=''>the</span> <span style=''>feedback</span> <span style=''>We</span> <span style=''>study</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>the</span> <span style=''>Bayesian</span> <span style=''>setting</span> <span style=''>In</span> <span style=''>presence</span> <span style=''>of</span> <span style=''>delays</span> <span style=''>no</span> <span style=''>solution</span> <span style=''>with</span> <span style=''>provable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantees</span> <span style=''>is</span> <span style=''>known</span> <span style=''>to</span> <span style=''>exist</span> <span style=''>with</span> <span style=''>sub</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exponential</span> <span style=''>running</span> <span style=''>time</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>bandit</span> <span style=''>problems</span> <span style=''>with</span> <span style=''>delayed</span> <span style=''>feedback</span> <span style=''>that</span> <span style=''>arise</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>allocation</span> <span style=''>settings</span> <span style=''>can</span> <span style=''>be</span> <span style=''>forced</span> <span style=''>to</span> <span style=''>have</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>significant</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>with</span> <span style=''>a</span> <span style=''>slight</span> <span style=''>loss</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimality</span> <span style=''>This</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>gives</span> <span style=''>us</span> <span style=''>the</span> <span style=''>ability</span> <span style=''>to</span> <span style=''>reason</span> <span style=''>about</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relationship</span> <span style=''>of</span> <span style=''>single</span> <span style=' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>with</span> <span style=''>many</span> <span style=''>experts</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>and</span> <span style=''>sparsity</span> <br/><br/><span style=''>Experts</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifying</span> <span style=''>data</span> <span style=''>are</span> <span style=''>often</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>imprecise</span> <span style=''>Recently</span> <span style=''>several</span> <span style=''>models</span> <span style=''>have</span> <span style=''>been</span> <span style=''>proposed</span> <span style=''>to</span> <span style=''>train</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>using</span> <span style=''>the</span> <span style=''>noisy</span> <span style=''>labels</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generated</span> <span style=''>by</span> <span style=''>these</span> <span style=''>experts</span> <span style=''>How</span> <span style=''>to</span> <span style=''>choose</span> <span style=''>between</span> <span style=''>these</span> <span style=''>models</span> <span style=''>In</span> <span style=''>such</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>situations</span> <span style=''>the</span> <span style=''>true</span> <span style=''>labels</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unavailable</span> <span style=''>Thus</span> <span style=''>one</span> <span style=''>cannot</span> <span style=''>perform</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>using</span> <span style=''>the</span> <span style=''>standard</span> <span style=''>versions</span> <span style=''>of</span> <span style=''>methods</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style=''>risk</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimization</span> <span style=''>and</span> <span style=''>cross</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>validation</span> <span style=''>In</span> <span style=''>order</span> <span style=''>to</span> <span style=''>allow</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>surrogate</span> <span style=''>loss</span> <span style=''>and</span> <span style=''>provide</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>guarantees</span> <span style=''>that</span> <span style=''>assure</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistency</span> <span style=''>Next</span> <span style=''>we</span> <span style=''>discuss</span> <span style=''>how</span> <span style=''>this</span> <span style=''>loss</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style=''>tune</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>penalization</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduces</span> <span style=''>sparsity</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>traditional</span> <span style=''>class</span> <span style=''>of</span> <span style=''>models</span> <span style=''>Sparsity</span> <span style=''>provides</span> <span style=''>more</span> <span style='background-color:rgba(0, 2 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>Differentially</span> <span style=''>Private</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Empirical</span> <span style=''>Risk</span> <span style='background-color:rgba(255, 0, 0, 0.31645569620253167);'>Minimization</span> <br/><br/><span style=''>Privacy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>preserving</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>are</span> <span style=''>crucial</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3170731707317073);'>increasingly</span> <span style=''>common</span> <span style=''>setting</span> <span style=''>in</span> <span style=''>which</span> <span style=''>personal</span> <span style=''>data</span> <span style=''>such</span> <span style=''>as</span> <span style=''>medical</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>financial</span> <span style=''>records</span> <span style=''>are</span> <span style=''>analyzed</span> <span style=''>We</span> <span style=''>provide</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>to</span> <span style=''>produce</span> <span style=''>privacy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>preserving</span> <span style='background-color:rgba(255, 0, 0, 0.5398230088495575);'>approximations</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifiers</span> <span style=''>learned</span> <span style=''>via</span> <span style=''>(regularized)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> <span style=''>risk</span> <span style='background-color:rgba(255, 0, 0, 0.31645569620253167);'>minimization</span> <span style=''>(ERM)</span> <span style=''>These</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>are</span> <span style=''>private</span> <span style=''>under</span> <span style=''>the</span> <span style=''>epsilon</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>differential</span> <span style=''>privacy</span> <span style='background-color:rgba(0, 255, 0, 0.34328358208955234);'>definition</span> <span style=''>due</span> <span style=''>to</span> <span style=''>Dwork</span> <span style=''>et</span> <span style=''>al</span> <span style=''>(2006)</span> <span style=''>First</span> <span style=''>we</span> <span style=''>apply</span> <span style=''>the</span> <span style=''>output</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perturbation</span> <span style=''>ideas</span> <span style=''>of</span> <span style=''>Dwork</span> <span style=''>et</span> <span style=''>al</span> <span style=''>(2006)</span> <span style=''>to</span> <span style=''>ERM</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>Then</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>method</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perturbation</span> <span style=''>for</span> <span style=''>privacy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>preserving</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>design</span> <span style=''>This</span> <span style=''>method</span> <span style=''>entails</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>perturbing</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>function</span> <span style=''>before</span> <span style='background-color ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Generalised</span> <span style=''>Reichenbachian</span> <span style=''>Common</span> <span style=''>Cause</span> <span style=''>Systems</span> <br/><br/><span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principle</span> <span style=''>of</span> <span style=''>the</span> <span style=''>common</span> <span style=''>cause</span> <span style=''>claims</span> <span style=''>that</span> <span style=''>if</span> <span style=''>an</span> <span style=''>improbable</span> <span style=''>coincidence</span> <span style=''>has</span> <span style=''>occurred</span> <span style=''>there</span> <span style=''>must</span> <span style=''>exist</span> <span style=''>a</span> <span style=''>common</span> <span style=''>cause</span> <span style=''>This</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generally</span> <span style=''>taken</span> <span style=''>to</span> <span style=''>mean</span> <span style=''>that</span> <span style=''>positive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlations</span> <span style=''>between</span> <span style=''>non</span> <span style=''>causally</span> <span style=''>related</span> <span style=''>events</span> <span style=''>should</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>disappear</span> <span style=''>when</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditioning</span> <span style=''>on</span> <span style=''>the</span> <span style=''>action</span> <span style=''>of</span> <span style=''>some</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>common</span> <span style=''>cause</span> <span style=''>The</span> <span style=''>extended</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretation</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principle</span> <span style=''>by</span> <span style=''>contrast</span> <span style=''>urges</span> <span style=''>that</span> <span style=''>common</span> <span style=''>causes</span> <span style=''>should</span> <span style=''>be</span> <span style=''>called</span> <span style=''>for</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>explain</span> <span style=''>positive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>deviations</span> <span style=''>between</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlation</span> <span style=''>of</span> <span style=''>two</span> <span style=''>events</span> <span style=''>and</span> <span style=''>the</span> <span style=''>expected</span> <span style=''>value</span> <span style=''>of</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlation</span> <span style=''>The</span> <span style=''>aim</span> <span style=''>of</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>is</span> <span style=''>to</span> <span style=''>provide</span> <span style=''>the</span> <span style=''>extended</span> <span style=''>reading</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principle</span> <span style=''>with</span> <span style=''>a</span> <span style=''>general</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>capturing</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simultaneous</span> <span style=''>action</span> <span style=''>of</span> <span style=''>a</span> <span style=''>system</span> <span style=''>of</span> <span style=''>multiple</span> <span style=''>common</span> <span style=''>causes</span> <span styl ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.12994960403167746)
# 	segmentation (0.06695464362850972)
# 	automatic (0.07307415406767459)
# 	architecture (0.08963282937365011)
# 	representation (0.13570914326853853)
# 	detection (0.11663066954643629)
# 	different (0.25593952483801297)
# 	information (0.25305975521958246)
# 	convolutional (0.13462922966162708)
# 	recognition (0.1378689704823614)
#
# Some Statistics words are:
# 	convergence (0.12660731948565776)
# 	theoretical (0.14886251236399603)
# 	variables (0.13402571711177053)
# 	estimation (0.16073194856577647)
# 	distribution (0.17606330365974282)
# 	algorithm (0.3818001978239367)
# 	statistical (0.15974282888229477)
# 	inference (0.18595450049455983)
# 	dimensional (0.1834817012858556)
# 	regression (0.1795252225519288)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a0fe6b60-97d6-492e-80e2-b539d5075ea3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a0fe6b60-97d6-492e-80e2-b539d5075ea3")) {                    Plotly.newPlot(                        "a0fe6b60-97d6-492e-80e2-b539d5075ea3",                        [{"x":["alternating","factoring","selecting","optimization","suppression","effectiveness","algorithm","important","formulate","promoting","minimization","fluorescence","iteration","simulations","regularization","procedure","factorization","separation","convergence","incorporated","applications","trilinear","constraints","experiments","iteratively","information","complexity","collected","framework","corresponding","reconstruction","keypoints","utilizing","performing","descriptor","photogrammetry","documentation","reconstructed","presented","comparing","preservation","commercial","texturing","parameter","beneficial","generalization","empirical","landscape","demonstrating","particular","outperforms","integrate","dimensionality","nonparametric","asymptotic","experimental","transition","factorial","contribution","probabilities","eliminate","redundant","selection","perplexity","extending","approximation","significantly","factorized","inference","challenging","variational","sequential","simultaneous","parsimonious","likelihood","competitive","visualizations","prediction","introduce","dimensional","visualize","nonetheless","visualization","difficult","subsequently","dependence","consequence","gradients","decompose","averaging","traditional","reduction","methodology","classification","structure","contributions","interpretation","visualized","advantages","projection","interpret","projections","furthermore","validated","splitting","robustness","interactions","regression","geometrical","qualities","specialized","classifiers","generative","distorted","arbitrary","attention","observations","simultaneously","symmetries","attributes","theoretical","improvement","organically","demonstrate","statistics","situation","baselines","different","recognized","refinement","qualitative","designing","quantitative","substantial","segmentation","guidelines","represented","autonomous","convolutional","evaluations","assessing","addressing","incomplete","correctly","simulated","correspond","adversarial","supervised","discriminator","efficient","generating","classifier","belonging","pertaining","discrepancy","distributions","conditions","connections","reproducing","projected","associated","divergences","incorporates","hypothesis","bhattacharyya","application","divergence","populations","neuroimaging","intermediate","characterize","differences","discriminate","approaches","investigated","systematic","simulation","additionally","providing","processes","algorithmic","considerations","computation","frequency","thresholded","tractable","decomposed","performance","graphical","otherwise","partition","connected","concentration","estimated","infeasible","components","thresholding","algorithms","covariance","denoising","successfully","coefficients","observation","deblurring","including","demonstrated","artifacts","transformed","deblocking","approximate","similarity","estimation","representation","reconstruct","modelling","stochastic","encountered","particularly","interpretable","conventional","overestimate","interpretability","tractably","mahalanobis","iterative","expensive","effectively","critically","researches","economical","computational","challenge","classical","describes","adaptivity","consecutive","scenarios","dependent","sometimes","environments","knowledge","implements","recognition","identifying","organizing","techniques","detection","objective","naturally","nonconvex","simplifies","landscapes","symmetric","efficiently","com ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	trilinear
# 	bhattacharyya
# 	tractably
# 	revolutionize
# 	intriguingly
# 	diagnostics
# 	heteroscedasticity
# 	hermitian
# 	subexponential
# 	precautions
# 	combinatorially
# 	triangles
# 	expository
# 	hoeffding
# 	inequalities
# 	disentanglement
# 	schizophrenia
# 	astronomy
# 	sparsities
# 	hamiltonians
# Some words which never appear in Statistics papers:
# 	keypoints
# 	photogrammetry
# 	texturing
# 	deblurring
# 	deblocking
# 	memristor
# 	acknowledged
# 	ontological
# 	existential
# 	predicate
# 	termination
# 	autonomously
# 	cooperative
# 	semantically
# 	introspective
# 	modularized
# 	indefinitely
# 	executing
# 	realistically
# 	confounds

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.087372645878358e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.78
